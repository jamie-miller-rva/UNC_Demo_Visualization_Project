# %%
# import dependencies
import pandas as pd

from json import loads, dumps

# %%
# read in superstore.orders.csv from data folder as a DataFrame
superstore_df = pd.read_csv("./data/superstore.orders.csv")
superstore_df
# Out:
#                             _id         Category           City  \
# 0      64a5ec6b01ab865a61af8cbf  Office Supplies        Houston
# 1      64a5ec6b01ab865a61af8cc0  Office Supplies     Naperville
# 2      64a5ec6b01ab865a61af8cc1  Office Supplies     Naperville
# 3      64a5ec6b01ab865a61af8cc2  Office Supplies     Naperville
# 4      64a5ec6b01ab865a61af8cc3  Office Supplies   Philadelphia
# ...                         ...              ...            ...
# 10189  64a5ec6c01ab865a61afb48c  Office Supplies  New York City
# 10190  64a5ec6c01ab865a61afb48d  Office Supplies      Fairfield
# 10191  64a5ec6c01ab865a61afb48e  Office Supplies       Loveland
# 10192  64a5ec6c01ab865a61afb48f       Technology  New York City
# 10193  64a5ec6c01ab865a61afb490  Office Supplies  Charlottetown
#
#       Country/Region      Customer Name  Manufacturer  \
# 0      United States      Darren Powers  Message Book
# 1      United States      Phillina Ober           GBC
# ...

# %%
# start EDA
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   _id             10194 non-null  object
#  1   Category        10194 non-null  object
#  2   City            10194 non-null  object
#  3   Country/Region  10194 non-null  object
#  4   Customer Name   10194 non-null  object
#  5   Manufacturer    10194 non-null  object
#  6   Order Date      10194 non-null  object
#  7   Order ID        10194 non-null  object
#  8   Postal Code     10194 non-null  object
#  9   Product Name    10194 non-null  object
#  10  Region          10194 non-null  object
#  11  Segment         10194 non-null  object
#  12  Ship Date       10194 non-null  object
#  13  Ship Mode       10194 non-null  object
#  14  State/Province  10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Discount        10194 non-null  float64
# ...

# %%
# view Order Date
superstore_df['Order Date'] = pd.to_datetime(superstore_df['Order Date'][1:])
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   _id             10194 non-null  object
#  1   Category        10194 non-null  object
#  2   City            10194 non-null  object
#  3   Country/Region  10194 non-null  object
#  4   Customer Name   10194 non-null  object
#  5   Manufacturer    10194 non-null  object
#  6   Order Date      10193 non-null  datetime64[ns]
#  7   Order ID        10194 non-null  object
#  8   Postal Code     10194 non-null  object
#  9   Product Name    10194 non-null  object
#  10  Region          10194 non-null  object
#  11  Segment         10194 non-null  object
#  12  Ship Date       10194 non-null  object
#  13  Ship Mode       10194 non-null  object
#  14  State/Province  10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Discount        10194 non-null  float64
# ...
